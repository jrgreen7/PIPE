# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# from http://www.ebi.ac.uk/Tools/webservices/psicquic/mint/webservices/current/search/query/species:yeast

# yeast_intra = pd.read_csv('data/species_yeast.txt', sep='\t', header=None);
# yeast_intra

# %% [markdown]
# ## Load PFAM domains for yeast

# %%
import re

# http://pfam.xfam.org/proteome/559292#tabview=tab2
# load in header row as single string # names are between angle brackets
yeast_pfam_header = re.findall(r'<(.*?)>', pd.read_csv('data/pfam_yeast_domains.tsv', sep='\n', header=2).columns[0]);

yeast_pfam_header
# Out:
# ['seq id',
#  'alignment start',
#  'alignment end',
#  'envelope start',
#  'envelope end',
#  'hmm acc',
#  'hmm name',
#  'type',
#  'hmm start',
#  'hmm end',
#  'hmm length',
#  'bit score',
#  'E-value',
#  'clan']

# %%
yeast_pfam = pd.read_csv('data/pfam_yeast_domains.tsv', sep='\t', names=yeast_pfam_header);

# %%
yeast_pfam.head()
# Out:
#                                               seq id  alignment start  \
# 0  #Pfam-A regions from Pfam version 33.1 for ncb...              NaN
# 1        #Total number of proteins in proteome: 6048              NaN
# 2  #<seq id> <alignment start> <alignment end> <e...              NaN
# 3                                         A0A0B7P3V8            621.0
# 4                                             A2P2R3             79.0
#
#    alignment end  envelope start  envelope end  hmm acc  hmm name    type  \
# 0            NaN             NaN           NaN      NaN       NaN     NaN
# 1            NaN             NaN           NaN      NaN       NaN     NaN
# 2            NaN             NaN           NaN      NaN       NaN     NaN
# 3          721.0           620.0         724.0  PF00665       rve  Domain
# 4          204.0            54.0         215.0  PF13522  GATase_6  Domain
#
#    hmm start  hmm end  hmm length  bit score       E-value    clan
# 0        NaN      NaN         NaN        NaN           NaN     NaN
# 1        NaN      NaN         NaN        NaN           NaN     NaN
# 2        NaN      NaN         NaN        NaN           NaN     NaN
# 3        2.0     99.0       102.0       52.0  1.800000e-10  CL0219
# 4       10.0    121.0       132.0       54.7  3.000000e-11  CL0052

# %%
yeast_pfam = yeast_pfam.drop(range(3)).reset_index(drop=True)
yeast_pfam.head(20)
# Out:
#         seq id  alignment start  alignment end  envelope start  envelope end  \
# 0   A0A0B7P3V8            621.0          721.0           620.0         724.0
# 1       A2P2R3             79.0          204.0            54.0         215.0
# 2       D6VPM8             24.0          117.0            14.0         120.0
# 3       D6VTK4             17.0          296.0            17.0         297.0
# 4       D6W196            231.0          335.0           225.0         337.0
# 5       D6W196            345.0          402.0           343.0         436.0
# 6       D6W196             89.0          107.0            87.0         110.0
# 7       D6W196             17.0           78.0            13.0          79.0
# 8       O13297            279.0          497.0           278.0         497.0
# 9       O13516            107.0          150.0           107.0         153.0
# 10      O13525             84.0          305.0            84.0         305.0
# 11      O13527            104.0          203.0           102.0         206.0
# 12      O13527            722.0          900.0           709.0         939.0
# 13      O13535            701.0          800.0           699.0         803.0
# 14      O13535             17.0          114.0            17.0         114.0
# 15      O13535           1319.0         1525.0          1309.0        1539.0
# 16      O13539            115.0          243.0           115.0         243.0
# 17      O13547             21.0           84.0            20.0          84.0
# 18      O13556             11.0           88.0             3.0          89.0
# 19      O13559            388.0          547.0           375.0         549.0
#
#     hmm acc      hmm name    type  hmm start  hmm end  hmm length  bit score  \
# 0   PF00665           rve  Domain        2.0     99.0       102.0       52.0
# 1   PF13522      GATase_6  Domain       10.0    121.0       132.0       54.7
# 2   PF00674           DUP  Family        9.0    100.0       103.0      115.8
# 3   PF02116          STE2  Family        1.0    279.0       280.0      304.9
# 4   PF00153     Mito_carr  Family        9.0     95.0        97.0       64.3
# 5   PF00153     Mito_carr  Family        3.0     60.0        97.0       32.7
# 6   PF13202     EF-hand_5  Domain        5.0     23.0        25.0       17.4
# 7   PF13499     EF-hand_7  Domain        5.0     69.0        70.0       35.0
# 8   PF02940  mRNA_triPase  Domain        2.0    221.0       221.0      253.8
# 9   PF01479            S4  Domain        1.0     44.0        48.0       45.8
# 10  PF05019          Coq4  Family        1.0    221.0       221.0      310.3
# 11  PF00665           rve  Domain        3.0     99.0       102.0       43.8
# 12  PF07727         RVT_2  Family       13.0    199.0       243.0      102.7
# 13  PF00665           rve  Domain        3.0     99.0       102.0       44.0
# 14  PF01021           TYA  Family        1.0     98.0        98.0      146.0
# 15  PF07727         RVT_2  Family       13.0    221.0       243.0      101.8
# 16  PF09432          THP2  Family        1.0    129.0       129.0      169.9
# 17  PF05730          CFEM  Domain        2.0     66.0        66.0       34.4
# 18  PF11603          Sir1  Domain       46.0    119.0       120.0       27.2
# 19  PF00270          DEAD  Domain       13.0    174.0       176.0       28.7
#
#          E-value     clan
# 0   1.800000e-10   CL0219
# 1   3.000000e-11   CL0052
# 2   2.200000e-30  No_clan
# 3   1.300000e-87  No_clan
# 4   2.000000e-14  No_clan
# 5   1.400000e-04  No_clan
# 6   5.700000e+00   CL0220
# 7   3.700000e-05   CL0220
# 8   3.500000e-72   CL0273
# 9   9.500000e-09   CL0492
# 10  1.500000e-89  No_clan
# 11  6.600000e-08   CL0219
# 12  6.000000e-26   CL0027
# 13  5.600000e-08   CL0219
# 14  9.700000e-40  No_clan
# 15  1.100000e-25   CL0027
# 16  6.400000e-47  No_clan
# 17  4.500000e-05  No_clan
# 18  1.000000e-02  No_clan
# 19  2.600000e-03   CL0023

# %%
yeast_pfam.shape
# Out:
# (7907, 14)

# %%
yeast_pfam['seq id'].unique().size
# Out:
# 4930

# %%
yeast_pfam['type'].unique()
# Out:
# array(['Domain', 'Family', 'Coiled-coil', 'Repeat', 'Motif', 'Disordered'],
#       dtype=object)

# %% [markdown]
# We are choosing to drop all types that are not explicitly domains

# %%
yeast_pfam_domains = yeast_pfam[yeast_pfam['type'] == 'Domain'].sort_values('seq id')
# yeast_pfam_domains = yeast_pfam
yeast_pfam_domains
# Out:
#           seq id  alignment start  alignment end  envelope start  \
# 0     A0A0B7P3V8            621.0          721.0           620.0
# 1         A2P2R3             79.0          204.0            54.0
# 6         D6W196             89.0          107.0            87.0
# 7         D6W196             17.0           78.0            13.0
# 8         O13297            279.0          497.0           278.0
# ...          ...              ...            ...             ...
# 7893      Q99383            162.0          223.0           161.0
# 7902      Q9ZZW7            269.0          367.0           268.0
# 7903      Q9ZZW7            405.0          499.0           405.0
# 7901      Q9ZZW7             18.0          199.0            17.0
# 7904      Q9ZZX0            201.0          296.0           201.0
#
#       envelope end  hmm acc      hmm name    type  hmm start  hmm end  \
# 0            724.0  PF00665           rve  Domain        2.0     99.0
# 1            215.0  PF13522      GATase_6  Domain       10.0    121.0
# 6            110.0  PF13202     EF-hand_5  Domain        5.0     23.0
# 7             79.0  PF13499     EF-hand_7  Domain        5.0     69.0
# 8            497.0  PF02940  mRNA_triPase  Domain        2.0    221.0
# ...            ...      ...           ...     ...        ...      ...
# 7893         229.0  PF00076         RRM_1  Domain        2.0     64.0
# 7902         369.0  PF00961   LAGLIDADG_1  Domain        2.0    100.0
# 7903         501.0  PF00961   LAGLIDADG_1  Domain        1.0    100.0
# 7901         208.0  PF00033  Cytochrome_B  Domain        2.0    183.0
# 7904         300.0  PF00961   LAGLIDADG_1  Domain        1.0     98.0
#
#       hmm length  bit score       E-value    clan
# 0          102.0       52.0  1.800000e-10  CL0219
# 1          132.0       54.7  3.000000e-11  CL0052
# 6           25.0       17.4  5.700000e+00  CL0220
# 7           70.0       35.0  3.700000e-05  CL0220
# 8          221.0      253.8  3.500000e-72  CL0273
# ...          ...        ...           ...     ...
# 7893        70.0       60.8  2.200000e-13  CL0221
# 7902       102.0       77.7  2.800000e-18  CL0324
# 7903       102.0       40.8  8.900000e-07  CL0324
# 7901       189.0      198.7  2.100000e-55  CL0328
# 7904       102.0       50.5  8.400000e-10  CL0324
#
# [3878 rows x 14 columns]

# %%
yeast_pfam_domains.reset_index(drop=True, inplace=True)
yeast_pfam_domains
# Out:
#           seq id  alignment start  alignment end  envelope start  \
# 0     A0A0B7P3V8            621.0          721.0           620.0
# 1         A2P2R3             79.0          204.0            54.0
# 2         D6W196             89.0          107.0            87.0
# 3         D6W196             17.0           78.0            13.0
# 4         O13297            279.0          497.0           278.0
# ...          ...              ...            ...             ...
# 3873      Q99383            162.0          223.0           161.0
# 3874      Q9ZZW7            269.0          367.0           268.0
# 3875      Q9ZZW7            405.0          499.0           405.0
# 3876      Q9ZZW7             18.0          199.0            17.0
# 3877      Q9ZZX0            201.0          296.0           201.0
#
#       envelope end  hmm acc      hmm name    type  hmm start  hmm end  \
# 0            724.0  PF00665           rve  Domain        2.0     99.0
# 1            215.0  PF13522      GATase_6  Domain       10.0    121.0
# 2            110.0  PF13202     EF-hand_5  Domain        5.0     23.0
# 3             79.0  PF13499     EF-hand_7  Domain        5.0     69.0
# 4            497.0  PF02940  mRNA_triPase  Domain        2.0    221.0
# ...            ...      ...           ...     ...        ...      ...
# 3873         229.0  PF00076         RRM_1  Domain        2.0     64.0
# 3874         369.0  PF00961   LAGLIDADG_1  Domain        2.0    100.0
# 3875         501.0  PF00961   LAGLIDADG_1  Domain        1.0    100.0
# 3876         208.0  PF00033  Cytochrome_B  Domain        2.0    183.0
# 3877         300.0  PF00961   LAGLIDADG_1  Domain        1.0     98.0
#
#       hmm length  bit score       E-value    clan
# 0          102.0       52.0  1.800000e-10  CL0219
# 1          132.0       54.7  3.000000e-11  CL0052
# 2           25.0       17.4  5.700000e+00  CL0220
# 3           70.0       35.0  3.700000e-05  CL0220
# 4          221.0      253.8  3.500000e-72  CL0273
# ...          ...        ...           ...     ...
# 3873        70.0       60.8  2.200000e-13  CL0221
# 3874       102.0       77.7  2.800000e-18  CL0324
# 3875       102.0       40.8  8.900000e-07  CL0324
# 3876       189.0      198.7  2.100000e-55  CL0328
# 3877       102.0       50.5  8.400000e-10  CL0324
#
# [3878 rows x 14 columns]

# %% [markdown]
# ### Create map of sequence IDs and their indices

# %%
yeast_pfam_domains['seq id'].unique().size
# Out:
# 2599

# %%
# Make unique uniprot IDs as index
yeast_pfam_indices = pd.Series(index=yeast_pfam_domains['seq id'].unique(), dtype=object)
yeast_pfam_indices
# Out:
# A0A0B7P3V8    NaN
# A2P2R3        NaN
# D6W196        NaN
# O13297        NaN
# O13516        NaN
#              ...
# Q99359        NaN
# Q99369        NaN
# Q99383        NaN
# Q9ZZW7        NaN
# Q9ZZX0        NaN
# Length: 2599, dtype: object

# %%
# Verify type of indices
print(type(yeast_pfam_indices.index[0]))
# Out:
# <class 'str'>

# %% [markdown]
# Find all locations in PFAM dataframe where index occurs and add it to map

# %%
for idx in yeast_pfam_indices.index:
    yeast_pfam_indices.loc[idx] = yeast_pfam_domains['seq id'][yeast_pfam_domains['seq id'] == idx].index

# %%
yeast_pfam_indices
# Out:
# A0A0B7P3V8                   Int64Index([0], dtype='int64')
# A2P2R3                       Int64Index([1], dtype='int64')
# D6W196                    Int64Index([2, 3], dtype='int64')
# O13297                       Int64Index([4], dtype='int64')
# O13516                       Int64Index([5], dtype='int64')
#                                   ...
# Q99359                    Int64Index([3870], dtype='int64')
# Q99369                    Int64Index([3871], dtype='int64')
# Q99383              Int64Index([3872, 3873], dtype='int64')
# Q9ZZW7        Int64Index([3874, 3875, 3876], dtype='int64')
# Q9ZZX0                    Int64Index([3877], dtype='int64')
# Length: 2599, dtype: object

# %% [markdown]
# Confirm that the map works

# %%
yeast_pfam_domains.loc[yeast_pfam_indices.iloc[0]]
# Out:
#        seq id  alignment start  alignment end  envelope start  envelope end  \
# 0  A0A0B7P3V8            621.0          721.0           620.0         724.0
#
#    hmm acc hmm name    type  hmm start  hmm end  hmm length  bit score  \
# 0  PF00665      rve  Domain        2.0     99.0       102.0       52.0
#
#         E-value    clan
# 0  1.800000e-10  CL0219

# %%
# http://pfam.xfam.org/protein/TUP1_YEAST
'P16649' in yeast_pfam_domains['seq id'].to_list()
# Out:
# True

# %%
yeast_pfam_domains.loc[yeast_pfam_indices['P16649']]
# Out:
#      seq id  alignment start  alignment end  envelope start  envelope end  \
# 611  P16649             11.0           88.0            11.0          88.0
#
#      hmm acc hmm name    type  hmm start  hmm end  hmm length  bit score  \
# 611  PF08581    Tup_N  Domain        1.0     77.0        77.0       98.6
#
#           E-value     clan
# 611  4.800000e-25  No_clan

# %%
# http://pfam.xfam.org/protein/CDC4_YEAST
yeast_pfam_domains.loc[yeast_pfam_domains['seq id']=='P07834']
# Out:
#      seq id  alignment start  alignment end  envelope start  envelope end  \
# 277  P07834            275.0          312.0           273.0         320.0
# 278  P07834            227.0          272.0           224.0         272.0
#
#      hmm acc hmm name    type  hmm start  hmm end  hmm length  bit score  \
# 277  PF00646    F-box  Domain        3.0     40.0        48.0       20.9
# 278  PF16856   CDC4_D  Domain        6.0     51.0        51.0       65.5
#
#           E-value     clan
# 277  6.200000e-01   CL0271
# 278  7.400000e-15  No_clan

# %%
'PF00400' in yeast_pfam_domains['hmm acc'].to_list()
# Out:
# False

# %% [markdown]
# For some reason WD40 isn't in the downloaded data
# EDIT: This is because we dropped all non-domains from the pfam database

# %%
# http://pfam.xfam.org/protein/MSI1_YEAST
'P13712' in yeast_pfam_domains['seq id'].to_list()
# Out:
# False

# %%
'PF12265' in yeast_pfam_domains['hmm acc']
# Out:
# False

# %% [markdown]
# Nor are some proteins

# %% [markdown]
# ## Load BioGRID Interactome for yeast

# %%
# downloaded from https://downloads.thebiogrid.org/File/BioGRID/Release-Archive/BIOGRID-4.2.191/BIOGRID-ORGANISM-4.2.191.tab3.zip

yeast_df = pd.read_csv("data/BIOGRID-ORGANISM-Saccharomyces_cerevisiae_S288c-4.2.191.tab3.txt",
                        sep = "\t")
# Out:
# C:\Users\mawil\Anaconda3\envs\SYSC4907\lib\site-packages\IPython\core\interactiveshell.py:3145: DtypeWarning: Columns (1,2,18) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
yeast_df.shape
# Out:
# (756225, 37)

# %%
yeast_df.head()
# Out:
#    #BioGRID Interaction ID Entrez Gene Interactor A Entrez Gene Interactor B  \
# 0                    68770                   851136                   854020
# 1                    68771                   854020                   851136
# 2                    68774                   851136                   854290
# 3                    68775                   854290                   851136
# 4                    68778                   851136                   852582
#
#    BioGRID ID Interactor A  BioGRID ID Interactor B  \
# 0                    31676                    34272
# 1                    34272                    31676
# 2                    31676                    34518
# 3                    34518                    31676
# 4                    31676                    32973
#
#   Systematic Name Interactor A Systematic Name Interactor B  \
# 0                      YLR418C                      YOL145C
# 1                      YOL145C                      YLR418C
# 2                      YLR418C                      YOR123C
# 3                      YOR123C                      YLR418C
# 4                      YLR418C                      YBR279W
#
#   Official Symbol Interactor A Official Symbol Interactor B  \
# 0                        CDC73                         CTR9
# 1                         CTR9                        CDC73
# 2                        CDC73                         LEO1
# 3                         LEO1                        CDC73
# 4                        CDC73                         PAF1
#
#   Synonyms Interactor A  ... TREMBL Accessions Interactor B  \
# 0            L000002792  ...                              -
# 1       CDP1|L000003477  ...                              -
# 2            L000002792  ...                              -
# 3            L000000936  ...                              -
# 4            L000002792  ...                              -
#
#   REFSEQ Accessions Interactor B Ontology Term IDs Ontology Term Names  \
# 0                      NP_014496                 -                   -
# 1                      NP_013522                 -                   -
# 2                      NP_014766                 -                   -
# 3                      NP_013522                 -                   -
# 4                      NP_009838                 -                   -
#
#   Ontology Term Categories  Ontology Term Qualifier IDs  \
# 0                        -                            -
# 1                        -                            -
# 2                        -                            -
# 3                        -                            -
# 4                        -                            -
#
#    Ontology Term Qualifier Names Ontology Term Types  \
# 0                              -                   -
# 1                              -                   -
# 2                              -                   -
# 3                              -                   -
# 4                              -                   -
#
#          Organism Name Interactor A        Organism Name Interactor B
# 0  Saccharomyces cerevisiae (S288c)  Saccharomyces cerevisiae (S288c)
# 1  Saccharomyces cerevisiae (S288c)  Saccharomyces cerevisiae (S288c)
# 2  Saccharomyces cerevisiae (S288c)  Saccharomyces cerevisiae (S288c)
# 3  Saccharomyces cerevisiae (S288c)  Saccharomyces cerevisiae (S288c)
# 4  Saccharomyces cerevisiae (S288c)  Saccharomyces cerevisiae (S288c)
#
# [5 rows x 37 columns]

# %%
yeast_df.columns
# Out:
# Index(['#BioGRID Interaction ID', 'Entrez Gene Interactor A',
#        'Entrez Gene Interactor B', 'BioGRID ID Interactor A',
#        'BioGRID ID Interactor B', 'Systematic Name Interactor A',
#        'Systematic Name Interactor B', 'Official Symbol Interactor A',
#        'Official Symbol Interactor B', 'Synonyms Interactor A',
#        'Synonyms Interactor B', 'Experimental System',
#        'Experimental System Type', 'Author', 'Publication Source',
#        'Organism ID Interactor A', 'Organism ID Interactor B', 'Throughput',
#        'Score', 'Modification', 'Qualifications', 'Tags', 'Source Database',
#        'SWISS-PROT Accessions Interactor A', 'TREMBL Accessions Interactor A',
#        'REFSEQ Accessions Interactor A', 'SWISS-PROT Accessions Interactor B',
#        'TREMBL Accessions Interactor B', 'REFSEQ Accessions Interactor B',
#        'Ontology Term IDs', 'Ontology Term Names', 'Ontology Term Categories',
#        'Ontology Term Qualifier IDs', 'Ontology Term Qualifier Names',
#        'Ontology Term Types', 'Organism Name Interactor A',
#        'Organism Name Interactor B'],
#       dtype='object')

# %%
yeast_df.iloc[0]
# Out:
# #BioGRID Interaction ID                                          68770
# Entrez Gene Interactor A                                        851136
# Entrez Gene Interactor B                                        854020
# BioGRID ID Interactor A                                          31676
# BioGRID ID Interactor B                                          34272
# Systematic Name Interactor A                                   YLR418C
# Systematic Name Interactor B                                   YOL145C
# Official Symbol Interactor A                                     CDC73
# Official Symbol Interactor B                                      CTR9
# Synonyms Interactor A                                       L000002792
# Synonyms Interactor B                                  CDP1|L000003477
# Experimental System                                Affinity Capture-MS
# Experimental System Type                                      physical
# Author                                                Krogan NJ (2004)
# Publication Source                                     PUBMED:14759368
# Organism ID Interactor A                                        559292
# Organism ID Interactor B                                        559292
# Throughput                                             High Throughput
# Score                                                                -
# Modification                                                         -
# Qualifications                                                       -
# Tags                                                                 -
# Source Database                                                BIOGRID
# SWISS-PROT Accessions Interactor A                              Q06697
# TREMBL Accessions Interactor A                                       -
# REFSEQ Accessions Interactor A                               NP_013522
# SWISS-PROT Accessions Interactor B                              P89105
# TREMBL Accessions Interactor B                                       -
# REFSEQ Accessions Interactor B                               NP_014496
# Ontology Term IDs                                                    -
# Ontology Term Names                                                  -
# Ontology Term Categories                                             -
# Ontology Term Qualifier IDs                                          -
# Ontology Term Qualifier Names                                        -
# Ontology Term Types                                                  -
# Organism Name Interactor A            Saccharomyces cerevisiae (S288c)
# Organism Name Interactor B            Saccharomyces cerevisiae (S288c)
# Name: 0, dtype: object

# %% [markdown]
# Many of the same sequences appear in a line as '|'

# %%
yeast_df['SWISS-PROT Accessions Interactor A'] = yeast_df['SWISS-PROT Accessions Interactor A'].apply(lambda s: s.split('|'))
yeast_df['SWISS-PROT Accessions Interactor B'] = yeast_df['SWISS-PROT Accessions Interactor B'].apply(lambda s: s.split('|'))
yeast_df = yeast_df.explode('SWISS-PROT Accessions Interactor A', ignore_index=True).explode('SWISS-PROT Accessions Interactor B', ignore_index=True)

# %%
yeast_df.shape
# Out:
# (769110, 37)

# %% [markdown]
# Drop all for where swiss-prot ID is not available

# %%
yeast_df.drop(yeast_df[yeast_df['SWISS-PROT Accessions Interactor A'] == '-'].index, inplace=True)
yeast_df.drop(yeast_df[yeast_df['SWISS-PROT Accessions Interactor B'] == '-'].index, inplace=True)
yeast_df.shape
# Out:
# (766596, 37)

# %% [markdown]
# ## Load domain-domain interactinos

# %%
# from https://3did.irbbarcelona.org/download.php
yeast_3DID = pd.read_csv("data/3did_flat_Apr_10_2020.dat",
                        sep = "\t", header = None,
                        names=range(7))

# %%
yeast_3DID.head()
# Out:
#       0           1           2                 3                4        5  \
# 0  #=ID  1-cysPrx_C  1-cysPrx_C   (PF10417.9@Pfam  PF10417.9@Pfam)      NaN
# 1  #=3D        5jcg   A:157-192         H:157-192              1.1  1.50646
# 2     Q           E        159               162                sm      NaN
# 3     Q           T        159               163                sm      NaN
# 4     E           Q        162               159                ms      NaN
#
#      6
# 0  NaN
# 1  2:2
# 2  NaN
# 3  NaN
# 4  NaN

# %%
# this is a flat database; find indices with #=ID, that's what we're interested in (domain domain pairs)
id_indices_3did = yeast_3DID[0].loc[yeast_3DID[0] == '#=ID'].index
id_indices_3did
# Out:
# Int64Index([       0,      489,    17346,    17505,    17551,    17560,
#                24675,    24777,    25600,    25610,
#             ...
#             21980373, 21981657, 21981733, 21981833, 21981862, 21982157,
#             21982178, 21983337, 21983498, 21983742],
#            dtype='int64', length=14278)

# %%
# strip all that are not those indices in non-pfam columns
yeast_3DID_pfam = yeast_3DID[[3,4]].iloc[id_indices_3did]
yeast_3DID_pfam
# Out:
#                           3                 4
# 0           (PF10417.9@Pfam   PF10417.9@Pfam)
# 489         (PF10417.9@Pfam  PF00578.21@Pfam)
# 17346       (PF10417.9@Pfam  PF02195.18@Pfam)
# 17505       (PF10417.9@Pfam  PF00085.20@Pfam)
# 17551       (PF12574.8@Pfam   PF12574.8@Pfam)
# ...                     ...               ...
# 21982157   (PF05707.12@Pfam  PF05707.12@Pfam)
# 21982178    (PF16916.5@Pfam   PF16916.5@Pfam)
# 21983337   (PF00791.20@Pfam  PF00791.20@Pfam)
# 21983498    (PF09817.9@Pfam   PF09817.9@Pfam)
# 21983742   (PF00569.17@Pfam  PF00569.17@Pfam)
#
# [14278 rows x 2 columns]

# %%
# Reformat so it's just pfam IDs
yeast_3DID_pfam.columns=["Pfam ID A","Pfam ID B"]
yeast_3DID_pfam.reset_index(inplace=True, drop=True)

import re
# yeast_3DID_pfam['Pfam ID A'] = yeast_3DID_pfam['Pfam ID A'].apply(lambda x: x.strip('@Pfam'))
# yeast_3DID_pfam['Pfam ID A'] = yeast_3DID_pfam['Pfam ID A'].apply(lambda x: x.strip('('))
yeast_3DID_pfam['Pfam ID A'] = yeast_3DID_pfam['Pfam ID A'].apply(lambda x: re.findall(r'\((.+?)\.', x)[0])
yeast_3DID_pfam['Pfam ID B'] = yeast_3DID_pfam['Pfam ID B'].apply(lambda x: re.findall(r'.*(?=\.)', x)[0])

yeast_3DID_pfam.head()
# Out:
#   Pfam ID A Pfam ID B
# 0   PF10417   PF10417
# 1   PF10417   PF00578
# 2   PF10417   PF02195
# 3   PF10417   PF00085
# 4   PF12574   PF12574

# %%
yeast_3DID_pfam
# Out:
#       Pfam ID A Pfam ID B
# 0       PF10417   PF10417
# 1       PF10417   PF00578
# 2       PF10417   PF02195
# 3       PF10417   PF00085
# 4       PF12574   PF12574
# ...         ...       ...
# 14273   PF05707   PF05707
# 14274   PF16916   PF16916
# 14275   PF00791   PF00791
# 14276   PF09817   PF09817
# 14277   PF00569   PF00569
#
# [14278 rows x 2 columns]

# %%
yeast_3DID_pfam['Pfam ID A'].unique().size
# Out:
# 7173

# %%
yeast_3DID_pfam['Pfam ID B'].unique().size
# Out:
# 7167

# %%
yeast_3DID_pfam[yeast_3DID_pfam['Pfam ID A'] == yeast_3DID_pfam['Pfam ID B'].iloc[1]]
# Out:
#     Pfam ID A Pfam ID B
# 749   PF00578   PF00578
# 750   PF00578   PF00881
# 751   PF00578   PF02195
# 752   PF00578   PF00085
# 753   PF00578   PF17991
# 754   PF00578   PF13905

# %%
yeast_3DID_pfam[yeast_3DID_pfam['Pfam ID B'] == yeast_3DID_pfam['Pfam ID B'].iloc[1]]
# Out:
#     Pfam ID A Pfam ID B
# 1     PF10417   PF00578
# 749   PF00578   PF00578

# %% [markdown]
# ### Create dictionary of domain pairs

# %%
pfam_pairs = pd.DataFrame(index=pd.concat([yeast_3DID_pfam['Pfam ID A'], yeast_3DID_pfam['Pfam ID B']]).unique(), columns=['pair values'])

# %%
pfam_pairs['pair values'] = [[] for _ in range(pfam_pairs.shape[0])]

# %%
pfam_pairs
# Out:
#         pair values
# PF10417          []
# PF12574          []
# PF00244          []
# PF00389          []
# PF02826          []
# ...             ...
# PF13894          []
# PF18366          []
# PF14835          []
# PF18586          []
# PF17979          []
#
# [8048 rows x 1 columns]

# %%
for A, B in zip(yeast_3DID_pfam['Pfam ID A'], yeast_3DID_pfam['Pfam ID B']):
    if B not in pfam_pairs['pair values'].loc[A]:
        pfam_pairs['pair values'].loc[A].append(B)

# %%
pfam_pairs
# Out:
#                                                pair values
# PF10417               [PF10417, PF00578, PF02195, PF00085]
# PF12574                                          [PF12574]
# PF00244  [PF00244, PF00583, PF03496, PF00130, PF00525, ...
# PF00389                        [PF00389, PF01842, PF11890]
# PF02826                        [PF02826, PF02222, PF17769]
# ...                                                    ...
# PF13894                                                 []
# PF18366                                                 []
# PF14835                                                 []
# PF18586                                                 []
# PF17979                                                 []
#
# [8048 rows x 1 columns]

# %%
for A, B in zip(yeast_3DID_pfam['Pfam ID A'], yeast_3DID_pfam['Pfam ID B']):
    if A not in pfam_pairs['pair values'].loc[B]:
        pfam_pairs['pair values'].loc[B].append(A)

# %%
pfam_pairs
# Out:
#                                                pair values
# PF10417               [PF10417, PF00578, PF02195, PF00085]
# PF12574                                          [PF12574]
# PF00244  [PF00244, PF00583, PF03496, PF00130, PF00525, ...
# PF00389                        [PF00389, PF01842, PF11890]
# PF02826                        [PF02826, PF02222, PF17769]
# ...                                                    ...
# PF13894                                          [PF00096]
# PF18366                                          [PF00096]
# PF14835                                          [PF00097]
# PF18586                                          [PF18585]
# PF17979                                          [PF10283]
#
# [8048 rows x 1 columns]

# %%
yeast_3DID_pfam[yeast_3DID_pfam['Pfam ID B'] == 'PF17979']
# Out:
#       Pfam ID A Pfam ID B
# 14231   PF10283   PF17979

# %%
pfam_pairs.loc['PF10283']
# Out:
# pair values    [PF17979]
# Name: PF10283, dtype: object

# %% [markdown]
# ## Find indices of sites for pairs

# %% [markdown]
# Create columns in yeast dataframe for domain pairs

# %%
yeast_df['domain_a'] = [[] for _ in range(yeast_df.shape[0])]
yeast_df['domain_b'] = [[] for _ in range(yeast_df.shape[0])]
yeast_df['domain_seq_a'] = [[] for _ in range(yeast_df.shape[0])]
yeast_df['domain_seq_b'] = [[] for _ in range(yeast_df.shape[0])]

# %%
yeast_pfam_domains['envelope start'] = yeast_pfam_domains['envelope start'].round(0).astype(np.int)
yeast_pfam_domains['envelope end'] = yeast_pfam_domains['envelope end'].round(0).astype(np.int)
yeast_pfam_domains['envelope start'], yeast_pfam_domains['envelope end']
# Out:
# (0       620
#  1        54
#  2        87
#  3        13
#  4       278
#         ...
#  3873    161
#  3874    268
#  3875    405
#  3876     17
#  3877    201
#  Name: envelope start, Length: 3878, dtype: int32,
#  0       724
#  1       215
#  2       110
#  3        79
#  4       497
#         ...
#  3873    229
#  3874    369
#  3875    501
#  3876    208
#  3877    300
#  Name: envelope end, Length: 3878, dtype: int32)

# %%
total_domains_found = 0
total_found = 0

for PA, PB, DA, DB, DSA, DSB in zip(yeast_df['SWISS-PROT Accessions Interactor A'], yeast_df['SWISS-PROT Accessions Interactor B'], yeast_df['domain_a'], yeast_df['domain_b'], yeast_df['domain_seq_a'], yeast_df['domain_seq_b']):
    found = False

    try:
        # Find locations in PFAM with relevant protein sequences
        pfam_indices_A = yeast_pfam_indices.loc[PA] 
        pfam_indices_B = yeast_pfam_indices.loc[PB]
        # Get iterable of PFAM IDs for domains for each protein
        # print(pfam_indices_A[0])
        pfam_ids_A = yeast_pfam_domains['hmm acc'].loc[pfam_indices_A]
        pfam_ids_B = yeast_pfam_domains['hmm acc'].loc[pfam_indices_B]
    except KeyError as inst:
#         print("No pfam entry found for protein")
#         print(inst.args)
        continue
    
    # for each domain PFAM id in A
    for pfam_index_A, pfam_id_A in pfam_ids_A.iteritems():
        # for each domain PFAM id in B
        for pfam_index_B, pfam_id_B in pfam_ids_B.iteritems():
            try:
                # get list of all domain interactions with B
                pfam_id_B_pairs = pfam_pairs['pair values'].loc[pfam_id_B]
            except KeyError as inst:
#                 print("No pairs found for domain " + inst.args[0])
                continue
            
            # if domain A is in the list of interactions for domain B, we have a match
            if pfam_id_A in pfam_id_B_pairs:

                # save domain starts and ends as tuples
                DA.append(pfam_id_A)
                DB.append(pfam_id_B)
                DSA.append((yeast_pfam_domains['envelope start'].loc[pfam_index_A], yeast_pfam_domains['envelope end'].loc[pfam_index_A]))
                DSB.append((yeast_pfam_domains['envelope start'].loc[pfam_index_B], yeast_pfam_domains['envelope end'].loc[pfam_index_B]))
                
                total_domains_found += 1
                found = True
    if found:
        total_found += 1

total_domains_found, total_found
# Out:
# (43651, 20419)

# %%
yeast_df
# Out:
#         #BioGRID Interaction ID Entrez Gene Interactor A  \
# 0                         68770                   851136
# 1                         68771                   854020
# 2                         68774                   851136
# 3                         68775                   854290
# 4                         68778                   851136
# ...                         ...                      ...
# 769105                  2874488                   854450
# 769106                  2874489                   854450
# 769107                  2874490                   854450
# 769108                  2874491                   854450
# 769109                  2874492                   854450
#
#        Entrez Gene Interactor B  BioGRID ID Interactor A  \
# 0                        854020                    31676
# 1                        851136                    34272
# 2                        854290                    31676
# 3                        851136                    34518
# 4                        852582                    31676
# ...                         ...                      ...
# 769105                   855907                    34665
# 769106                   856136                    34665
# 769107                   856158                    34665
# 769108                   856184                    34665
# 769109                   856281                    34665
#
#         BioGRID ID Interactor B Systematic Name Interactor A  \
# 0                         34272                      YLR418C
# 1                         31676                      YOL145C
# 2                         34518                      YLR418C
# 3                         31676                      YOR123C
# 4                         32973                      YLR418C
# ...                         ...                          ...
# 769105                    35989                      YOR276W
# 769106                    36202                      YOR276W
# 769107                    36221                      YOR276W
# 769108                    36243                      YOR276W
# 769109                    36325                      YOR276W
#
#        Systematic Name Interactor B Official Symbol Interactor A  \
# 0                           YOL145C                        CDC73
# 1                           YLR418C                         CTR9
# 2                           YOR123C                        CDC73
# 3                           YLR418C                         LEO1
# 4                           YBR279W                        CDC73
# ...                             ...                          ...
# 769105                      YPL194W                        CAF20
# 769106                      YPR025C                        CAF20
# 769107                      YPR045C                        CAF20
# 769108                      YPR071W                        CAF20
# 769109                      YPR158W                        CAF20
#
#        Official Symbol Interactor B                 Synonyms Interactor A  \
# 0                              CTR9                            L000002792
# 1                             CDC73                       CDP1|L000003477
# 2                              LEO1                            L000002792
# 3                             CDC73                            L000000936
# 4                              PAF1                            L000002792
# ...                             ...                                   ...
# 769105                         DDC1  CAF2|CAP20|p20|L000000208|L000003291
# 769106                         CCL1  CAF2|CAP20|p20|L000000208|L000003291
# 769107                         THP3  CAF2|CAP20|p20|L000000208|L000003291
# 769108                      YPR071W  CAF2|CAP20|p20|L000000208|L000003291
# 769109                         CUR1  CAF2|CAP20|p20|L000000208|L000003291
#
#         ... Ontology Term Categories Ontology Term Qualifier IDs  \
# 0       ...                        -                           -
# 1       ...                        -                           -
# 2       ...                        -                           -
# 3       ...                        -                           -
# 4       ...                        -                           -
# ...     ...                      ...                         ...
# 769105  ...                        -                           -
# 769106  ...                        -                           -
# 769107  ...                        -                           -
# 769108  ...                        -                           -
# 769109  ...                        -                           -
#
#        Ontology Term Qualifier Names Ontology Term Types  \
# 0                                  -                   -
# 1                                  -                   -
# 2                                  -                   -
# 3                                  -                   -
# 4                                  -                   -
# ...                              ...                 ...
# 769105                             -                   -
# 769106                             -                   -
# 769107                             -                   -
# 769108                             -                   -
# 769109                             -                   -
#
#               Organism Name Interactor A        Organism Name Interactor B  \
# 0       Saccharomyces cerevisiae (S288c)  Saccharomyces cerevisiae (S288c)
# 1       Saccharomyces cerevisiae (S288c)  Saccharomyces cerevisiae (S288c)
# 2       Saccharomyces cerevisiae (S288c)  Saccharomyces cerevisiae (S288c)
# 3       Saccharomyces cerevisiae (S288c)  Saccharomyces cerevisiae (S288c)
# 4       Saccharomyces cerevisiae (S288c)  Saccharomyces cerevisiae (S288c)
# ...                                  ...                               ...
# 769105  Saccharomyces cerevisiae (S288c)  Saccharomyces cerevisiae (S288c)
# 769106  Saccharomyces cerevisiae (S288c)  Saccharomyces cerevisiae (S288c)
# 769107  Saccharomyces cerevisiae (S288c)  Saccharomyces cerevisiae (S288c)
# 769108  Saccharomyces cerevisiae (S288c)  Saccharomyces cerevisiae (S288c)
# 769109  Saccharomyces cerevisiae (S288c)  Saccharomyces cerevisiae (S288c)
#
#         domain_a domain_b domain_seq_a domain_seq_b
# 0             []       []           []           []
# 1             []       []           []           []
# 2             []       []           []           []
# 3             []       []           []           []
# 4             []       []           []           []
# ...          ...      ...          ...          ...
# 769105        []       []           []           []
# 769106        []       []           []           []
# 769107        []       []           []           []
# 769108        []       []           []           []
# 769109        []       []           []           []
#
# [766596 rows x 41 columns]

# %% [markdown]
# ## Generate masks

# %% [markdown]
# Filter for ones where we only found a single domain interaction pair

# %%
yeast_single_site = yeast_df[yeast_df.domain_a.str.len() == 1].reset_index()
yeast_single_site
# Out:
#         index  #BioGRID Interaction ID Entrez Gene Interactor A  \
# 0          58                    68964                   855476
# 1         153                    71292                   856463
# 2         167                    71306                   856463
# 3         168                    71307                   856463
# 4         179                    71318                   856463
# ...       ...                      ...                      ...
# 12912  768188                  2822383                   851177
# 12913  768189                  2822384                   851177
# 12914  768220                  2822415                   853167
# 12915  768222                  2822417                   853167
# 12916  768290                  2873367                   854026
#
#       Entrez Gene Interactor B  BioGRID ID Interactor A  \
# 0                       856570                    35594
# 1                       854078                    36498
# 2                       856488                    36498
# 3                       853956                    36498
# 4                       856463                    36498
# ...                        ...                      ...
# 12912                   851810                    31714
# 12913                   851811                    31714
# 12914                   852373                    33503
# 12915                   853167                    33503
# 12916                   853071                    34278
#
#        BioGRID ID Interactor B Systematic Name Interactor A  \
# 0                        36599                      YNL245C
# 1                        34325                      YHR066W
# 2                        36523                      YHR066W
# 3                        34212                      YHR066W
# 4                        36498                      YHR066W
# ...                        ...                          ...
# 12912                    32276                      YLR455W
# 12913                    32277                      YLR455W
# 12914                    32783                      YGR252W
# 12915                    33503                      YGR252W
# 12916                    33414                      YOL139C
#
#       Systematic Name Interactor B Official Symbol Interactor A  \
# 0                          YHR165C                        CWC25
# 1                          YOL077C                         SSF1
# 2                          YHR088W                         SSF1
# 3                          YKR081C                         SSF1
# 4                          YHR066W                         SSF1
# ...                            ...                          ...
# 12912                      YDR224C                         PDP3
# 12913                      YDR225W                         PDP3
# 12914                      YBR081C                         GCN5
# 12915                      YGR252W                         GCN5
# 12916                      YGR162W                        CDC33
#
#       Official Symbol Interactor B  ... Ontology Term Categories  \
# 0                             PRP8  ...                        -
# 1                             BRX1  ...                        -
# 2                             RPF1  ...                        -
# 3                             RPF2  ...                        -
# 4                             SSF1  ...                        -
# ...                            ...  ...                      ...
# 12912                         HTB1  ...                        -
# 12913                         HTA1  ...                        -
# 12914                         SPT7  ...                        -
# 12915                         GCN5  ...                        -
# 12916                      TIF4631  ...                        -
#
#       Ontology Term Qualifier IDs Ontology Term Qualifier Names  \
# 0                               -                             -
# 1                               -                             -
# 2                               -                             -
# 3                               -                             -
# 4                               -                             -
# ...                           ...                           ...
# 12912                           -                             -
# 12913                           -                             -
# 12914                           -                             -
# 12915                           -                             -
# 12916                           -                             -
#
#       Ontology Term Types        Organism Name Interactor A  \
# 0                       -  Saccharomyces cerevisiae (S288c)
# 1                       -  Saccharomyces cerevisiae (S288c)
# 2                       -  Saccharomyces cerevisiae (S288c)
# 3                       -  Saccharomyces cerevisiae (S288c)
# 4                       -  Saccharomyces cerevisiae (S288c)
# ...                   ...                               ...
# 12912                   -  Saccharomyces cerevisiae (S288c)
# 12913                   -  Saccharomyces cerevisiae (S288c)
# 12914                   -  Saccharomyces cerevisiae (S288c)
# 12915                   -  Saccharomyces cerevisiae (S288c)
# 12916                   -  Saccharomyces cerevisiae (S288c)
#
#              Organism Name Interactor B   domain_a   domain_b  domain_seq_a  \
# 0      Saccharomyces cerevisiae (S288c)  [PF10197]  [PF10596]    [(11, 47)]
# 1      Saccharomyces cerevisiae (S288c)  [PF04427]  [PF04427]   [(34, 341)]
# 2      Saccharomyces cerevisiae (S288c)  [PF04427]  [PF04427]   [(34, 341)]
# 3      Saccharomyces cerevisiae (S288c)  [PF04427]  [PF04427]   [(34, 341)]
# 4      Saccharomyces cerevisiae (S288c)  [PF04427]  [PF04427]   [(34, 341)]
# ...                                 ...        ...        ...           ...
# 12912  Saccharomyces cerevisiae (S288c)  [PF00855]  [PF00125]     [(5, 97)]
# 12913  Saccharomyces cerevisiae (S288c)  [PF00855]  [PF00125]     [(5, 97)]
# 12914  Saccharomyces cerevisiae (S288c)  [PF00439]  [PF00439]  [(336, 419)]
# 12915  Saccharomyces cerevisiae (S288c)  [PF00439]  [PF00439]  [(336, 419)]
# 12916  Saccharomyces cerevisiae (S288c)  [PF01652]  [PF12152]   [(38, 196)]
#
#          domain_seq_b
# 0      [(1514, 1672)]
# 1         [(38, 224)]
# 2        [(101, 269)]
# 3         [(35, 236)]
# 4         [(34, 341)]
# ...               ...
# 12912      [(1, 105)]
# 12913       [(4, 92)]
# 12914    [(449, 530)]
# 12915    [(336, 419)]
# 12916    [(400, 469)]
#
# [12917 rows x 42 columns]

# %%
# Split out into numpy arrays
Uniprot_id_A = yeast_single_site['SWISS-PROT Accessions Interactor A'].to_numpy()
Uniprot_id_B = yeast_single_site['SWISS-PROT Accessions Interactor B'].to_numpy()
domain_pfam_a = yeast_single_site['domain_a'].to_numpy()
domain_pfam_b = yeast_single_site['domain_b'].to_numpy()
positions_a = yeast_single_site['domain_seq_a'].to_numpy()
positions_b = yeast_single_site['domain_seq_b'].to_numpy()

# %% [markdown]
# Load reference proteome for yeast

# %%
# reference proteome at https://www.uniprot.org/proteomes/UP000002311
# general proteome (reviewed S. cerevisiae) at https://www.uniprot.org/uniprot/?query=taxonomy:%22Saccharomyces%20cerevisiae%20(strain%20ATCC%20204508%20/%20S288c)%20(Baker%27s%20yeast)%20[559292]%22&fil=organism%3A%22Saccharomyces+cerevisiae+%28strain+ATCC+204508+%2F+S288c%29+%28Baker%27s+yeast%29+%5B559292%5D%22+AND+reviewed%3Ayes
uniprot_df = pd.read_csv("data/uniprot-proteome UP000002311.tab",
                        sep = "\t", index_col='Entry')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-45de165a3fec> in <module>
#       1 # reference proteome at https://www.uniprot.org/proteomes/UP000002311
#       2 # general proteome (reviewed S. cerevisiae) at https://www.uniprot.org/uniprot/?query=taxonomy:%22Saccharomyces%20cerevisiae%20(strain%20ATCC%20204508%20/%20S288c)%20(Baker%27s%20yeast)%20[559292]%22&fil=organism%3A%22Saccharomyces+cerevisiae+%28strain+ATCC+204508+%2F+S288c%29+%28Baker%27s+yeast%29+%5B559292%5D%22+AND+reviewed%3Ayes
# ----> 3 uniprot_df = pd.read_csv("data/uniprot-proteome UP000002311.tab",
#       4                         sep = "\t", index_col='Entry')
#
# NameError: name 'pd' is not defined

# %%
uniprot_df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-791a73aa7cd5> in <module>
# ----> 1 uniprot_df.head()
#
# NameError: name 'uniprot_df' is not defined

# %%
site_masks = []

for UA, UB, DA, DB, PA, PB in zip(Uniprot_id_A, Uniprot_id_B, domain_pfam_a, domain_pfam_b, positions_a, positions_b):
    interaction_area = 0
    try:
        # initialize mask with dimensions of protein sequence
        mask = np.zeros((uniprot_df['Length'].loc[UA], uniprot_df['Length'].loc[UB]), dtype=int)
        for pos_A, pos_B in zip(PA, PB):
            # print(pos_A, pos_B, mask.shape)
            # calculate area of interaction
            interaction_area += (pos_A[1]-pos_A[0])*(pos_B[1]-pos_B[0])
            # set area of interaction to 1
            mask[(pos_A[0]-1):(pos_A[1]-1), (pos_B[0]-1):(pos_B[1]-1)] = 1 # -1 as protein indexing starts by 0
        
        # filter for smaller interaction areas - we don't want to do the whole protein
        if interaction_area <= 0.5 * mask.shape[0]*mask.shape[1]:
            site_masks.append(mask)
        else:
            site_masks.append(np.NaN)
    except KeyError as inst:
        print(UA, UB)
        print("No uniprot entry found for protein")
        print(inst.args)
        site_masks.append(np.NaN)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-0898f13c84a7> in <module>
#       1 site_masks = []
#       2
# ----> 3 for UA, UB, DA, DB, PA, PB in zip(Uniprot_id_A, Uniprot_id_B, domain_pfam_a, domain_pfam_b, positions_a, positions_b):
#       4     interaction_area = 0
#       5     try:
#
# NameError: name 'Uniprot_id_A' is not defined

# %%
site_masks = np.asarray(site_masks)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-ce4be0dc7a8d> in <module>
# ----> 1 site_masks = np.asarray(site_masks)
#
# NameError: name 'np' is not defined

# %%
# Turn back into pandas dataframe
masks_domainsOnly = pd.DataFrame({'Uniprot ID A': Uniprot_id_A,
                                            'Uniprot ID B': Uniprot_id_B,
                                            'Domain_id_a': domain_pfam_a,
                                            'Domain_id_b': domain_pfam_b,
                                            'Domain positions A': positions_a,
                                            'Domain positions B': positions_b,
                                            'Sites Masks': site_masks})
# drop all masks for proteins we could not find/area was > 50%
masks_domainsOnly.dropna(inplace=True)
masks_domainsOnly.reset_index(drop=True, inplace=True)
masks_domainsOnly
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-35c148ecaeb6> in <module>
#       1 # Turn back into pandas dataframe
# ----> 2 masks_domainsOnly = pd.DataFrame({'Uniprot ID A': Uniprot_id_A,
#       3                                             'Uniprot ID B': Uniprot_id_B,
#       4                                             'Domain_id_a': domain_pfam_a,
#       5                                             'Domain_id_b': domain_pfam_b,
#
# NameError: name 'pd' is not defined

# %%
masks_domainsOnly['Sites Masks'].iloc[0].sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-0609c8f7260b> in <module>
# ----> 1 masks_domainsOnly['Sites Masks'].iloc[0].sum()
#
# NameError: name 'masks_domainsOnly' is not defined

# %% [markdown]
# ### Plot sample of masks

# %%
fig, axs = plt.subplots(10,10, figsize=(20, 20))
fig.set_tight_layout(True)
for i, ax in enumerate(axs.flat):
    ax.set_aspect('auto', adjustable='box')
    ax.matshow(masks_domainsOnly['Sites Masks'].iloc[i])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-70f97e383c53> in <module>
# ----> 1 fig, axs = plt.subplots(10,10, figsize=(20, 20))
#       2 fig.set_tight_layout(True)
#       3 for i, ax in enumerate(axs.flat):
#       4     ax.set_aspect('auto', adjustable='box')
#       5     ax.matshow(masks_domainsOnly['Sites Masks'].iloc[i])
#
# NameError: name 'plt' is not defined

# %%
masks_domainsOnly.to_pickle('data/masks_singlesite_domains_only.pkl')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-965d7d357e6f> in <module>
# ----> 1 masks_domainsOnly.to_pickle('data/masks_singlesite_domains_only.pkl')
#
# NameError: name 'masks_domainsOnly' is not defined
